# %% [markdown]
# # Scraping Wikipedia for postal codes of Canada

# %% [markdown]
# ## Here starts part one.

# %% [markdown]
# Import necessary modules for web scraping and dataframe generation:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Use given URL to scrape Wikipedia and BeautifulSoup to get wanted data from this url:

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# Find table with postal code data:

# %%
table = soup.find('table', attrs={'class':'wikitable sortable'})
table_body = table.find('tbody')
rows = table_body.find_all('tr')

# %% [markdown]
# For each row in the table delete trailing "\n". Skip the 'Not assigned' rows for the Borough column and if there is a neighbourhood with a 'Not assigned' value, use the value for borough instead. Create a dataframe from this iteration.

# %%
l = []
for tr in rows: #iterate through each row
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    r = [p.split('\n')[0] for p in row] #get rid of trainling '\n'
    try:
        if r[1] != 'Not assigned': #skip 'not assigned' boroughs
            if r[2] == 'Not assigned': #for 'not assigned' neighbourhoods use value of borough instead
                r[2] = r[1]
            l.append(r)
    except:
        pass
postal = pd.DataFrame(l, columns=["Postal Code", "Borough", "Neighbourhood"])#create pd.DataFrame
postal = postal.sort_values('Postal Code').reset_index().drop(columns=['index'])#sort by postal code, drop index column
postal
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                          Neighbourhood
# 0                                       Malvern, Rouge
# 1               Rouge Hill, Port Union, Highland Creek
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# ..                                                 ...
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village, St. Phillips, Martin Grove ...
# 101  South Steeles, Silverstone, Humbergate, Jamest...
# 102                Northwest, West Humber - Clairville
#
# [103 rows x 3 columns]

# %% [markdown]
# Get geospatial data for each postal code area from csv file:

# %% [markdown]
# ## Here starts part two.

# %% [markdown]
# Load csv file with geospatial coordinates:

# %%
geocoords = pd.read_csv('Geospatial_Coordinates.csv')

# %% [markdown]
# Copy the latitude and longitude data in the postal code dataframe:

# %%
postal['Latitude'] = geocoords['Latitude']
postal['Longitude'] = geocoords['Longitude']

# %% [markdown]
# Filter dataframe to find data for Toronto only:

# %%
tor = [x for x in list(postal['Borough'].drop_duplicates().value_counts().index) if x.find('Toronto') > -1]
df_tor = postal[(postal['Borough'] == tor[0]) | 
                (postal['Borough'] == tor[1]) | 
                (postal['Borough'] == tor[2]) | 
                (postal['Borough'] == tor[3])].sort_values('Borough').reset_index().drop(columns = 'index')
df_tor
# Out:
#    Postal Code           Borough  \
# 0          M5R   Central Toronto
# 1          M5P   Central Toronto
# 2          M4N   Central Toronto
# 3          M4P   Central Toronto
# 4          M4R   Central Toronto
# 5          M4S   Central Toronto
# 6          M4T   Central Toronto
# 7          M4V   Central Toronto
# 8          M5N   Central Toronto
# 9          M5J  Downtown Toronto
# 10         M5S  Downtown Toronto
# 11         M5L  Downtown Toronto
# 12         M5K  Downtown Toronto
# 13         M7A  Downtown Toronto
# 14         M5H  Downtown Toronto
# 15         M5G  Downtown Toronto
# 16         M5A  Downtown Toronto
# 17         M5C  Downtown Toronto
# 18         M5B  Downtown Toronto
# 19         M5T  Downtown Toronto
# 20         M4Y  Downtown Toronto
# 21         M4X  Downtown Toronto
# 22         M4W  Downtown Toronto
# 23         M5W  Downtown Toronto
# 24         M5X  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M5E  Downtown Toronto
# 27         M5V  Downtown Toronto
# 28         M4E      East Toronto
# 29         M4L      East Toronto
# 30         M4K      East Toronto
# 31         M4M      East Toronto
# 32         M7Y      East Toronto
# 33         M6H      West Toronto
# 34         M6J      West Toronto
# 35         M6K      West Toronto
# 36         M6P      West Toronto
# 37         M6R      West Toronto
# 38         M6S      West Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 1     Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 2                                       Lawrence Park  43.728020 -79.388790
# 3                                    Davisville North  43.712751 -79.390197
# 4                  North Toronto West,  Lawrence Park  43.715383 -79.405678
# 5                                          Davisville  43.704324 -79.388790
# 6                         Moore Park, Summerhill East  43.689574 -79.383160
# 7   Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 8                                            Roselawn  43.711695 -79.416936
# 9   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 10                     University of Toronto, Harbord  43.662696 -79.400049
# 11                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 12           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 13        Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 14                           Richmond, Adelaide, King  43.650571 -79.384568
# 15                                 Central Bay Street  43.657952 -79.387383
# 16                          Regent Park, Harbourfront  43.654260 -79.360636
# 17                                     St. James Town  43.651494 -79.375418
# 18                           Garden District, Ryerson  43.657162 -79.378937
# 19          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 20                               Church and Wellesley  43.665860 -79.383160
# 21                        St. James Town, Cabbagetown  43.667967 -79.367675
# 22                                           Rosedale  43.679563 -79.377529
# 23                                     Stn A PO Boxes  43.646435 -79.374846
# 24             First Canadian Place, Underground city  43.648429 -79.382280
# 25                                           Christie  43.669542 -79.422564
# 26                                        Berczy Park  43.644771 -79.373306
# 27  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 28                                        The Beaches  43.676357 -79.293031
# 29                     India Bazaar, The Beaches West  43.668999 -79.315572
# 30                       The Danforth West, Riverdale  43.679557 -79.352188
# 31                                    Studio District  43.659526 -79.340923
# 32  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 33                       Dufferin, Dovercourt Village  43.669005 -79.442259
# 34                           Little Portugal, Trinity  43.647927 -79.419750
# 35       Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 36                      High Park, The Junction South  43.661608 -79.464763
# 37                             Parkdale, Roncesvalles  43.648960 -79.456325
# 38                                 Runnymede, Swansea  43.651571 -79.484450

# %% [markdown]
# ## Here starts part three.

# %% [markdown]
# Import modules for fetching geo data, k-means clustering and map plotting:

# %%
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import numpy as np
import matplotlib.colors as colors

# !pip install folium
import folium # map rendering library
# Out:
# Requirement already satisfied: folium in c:\users\ar89n\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy in c:\users\ar89n\anaconda3\lib\site-packages (from folium) (1.18.0)
# Requirement already satisfied: branca>=0.3.0 in c:\users\ar89n\anaconda3\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ar89n\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in c:\users\ar89n\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ar89n\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\ar89n\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\ar89n\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ar89n\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ar89n\anaconda3\lib\site-packages (from requests->folium) (1.25.7)

# %% [markdown]
# Cluster data with KMeans from sklearn, use 4 clusters for the fit since we have four different boroughs in Toronto. Use the folium package for showing the result.

# %%
toronto_map = folium.Map(location=[43.67, -79.4], zoom_start=12)

X = df_tor['Latitude']
Y = df_tor['Longitude']
Z = np.stack((X, Y), axis=1)

colors = ['red', 'green', 'blue', 'yellow']
kmeans = KMeans(n_clusters=len(colors), random_state=42).fit(Z)
df_tor['Cluster'] = kmeans.labels_

for latitude, longitude, borough, cluster in zip(df_tor['Latitude'], df_tor['Longitude'], 
                                                 df_tor['Borough'], df_tor['Cluster']):
    label = folium.Popup(borough, parse_html=True)
    folium.CircleMarker(
        [latitude, longitude],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color=colors[cluster],
        fill_opacity=0.7).add_to(toronto_map)  

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3935cf4b2cbd448a9498a8b34625b131%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3935cf4b2cbd448a9498a8b34625b131%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3935cf4b2cbd448a9498a8b34625b131%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3935cf4b2cbd448a9498a8b34625b131%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.67%2C%20-79.4%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...
